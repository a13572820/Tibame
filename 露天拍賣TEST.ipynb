# %%
import requests
from bs4 import BeautifulSoup
headers = { 'Cookie': '_ga=GA1.3.758728240.1582273541; _fbp=fb.2.1582273540834.1783175331; _ts_id=3705330130023101380D.1582273540; __gads=ID=3d9ccafde4e4fa85:T=1582273540:S=ALNI_MYZH3TCBM8YxgpJwHPpW05IdEcQfQ; advanced-history=[[%2221708332931302%22%2C%220014003000020004%22]]; interest-rate=[[%220014%22%2C1]]; _gid=GA1.3.692069049.1589412738; fwchk=xWA7YENTnRAJzwkgQAfCgzeIlVg0001',
 'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'
}
res = requests.get('https://www.ruten.com.tw/',headers = headers)
soup = BeautifulSoup(res.text, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>ÅS¤Ñ©ç½æ-¥xÆW NO.1 ©ç½æºô¯¸</title>
# <meta content="¥xÆW³Ì¤j©ç½æºô¯¸¡A2018¦~¥­¥x¦¨¥æª÷ÃB¹F3305»õ¤¸¡A¥þ¯¸¶W¹L4»õ¥ó°Ó«~¼Æ¡A¬O¥@¬É²Ä¥|¤j©ç½æ¥­¥x¡A¤]¬O¥þ¥x·|­û³Ì¦h¡Bª«¥óÂ×´IªºAI¹q°Ó¥­¥x¡C" name="description"/>
# <meta content="text/css" http-equiv="content-style-type"/>
# <meta content="default" http-equiv="default-style"/>
# <meta content="text/javascript" http-equiv="content-script-type"/>
# <meta content="KsGmf_NIFg6_adR_7gn1e8vshmYNrtDtClA20HrsJXA" name="google-site-verification"/>
# <meta content="jO41s5R0m6xXGEO6ltvf3CC2HS4" name="alexaVerifyID"/>
# <link href="/" rel="home" title="ÅS¤Ñ©ç½æ­º­¶"/>
# <link href="https://www.ruten.com.tw/images/ie9_icon/logo_6464.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://www.ruten.com.tw/images/ie9_icon/logo_1616.ico" rel="shortcut icon" type="image/x-icon"/>
# ...

# %%
links = soup.find_all("link")
for link in links:
    href = link.get("href")  
    if href != None and href.startswith("https://"):
        print(href)
# Out:
# https://www.ruten.com.tw/images/ie9_icon/logo_6464.ico
# https://www.ruten.com.tw/images/ie9_icon/logo_1616.ico
# https://www.ruten.com.tw/css/jquery-ui-1.9.0.custom.min.css?v=20171123
# https://www.ruten.com.tw/css/jquery.ui.theme.css?v=20171123
# https://www.ruten.com.tw/css/d/v2/style-reset.css?v=20171123
# https://www.ruten.com.tw/css/d/v2/style-base.css?v=20200401_bf28e1abd3
# https://www.ruten.com.tw/css/d/v2/style-index.css?v=20200327_493d8d284c

# %%
link
# Out:
# <link href="https://www.ruten.com.tw/css/d/v2/style-index.css?v=20200327_493d8d284c" rel="stylesheet" type="text/css"/>
